# %% [markdown]
# # Top 10 Python Extensions - For Data Science & Machine Learning

# %% [markdown]
# ------------
# ------------

# %%
# Assignment #01 - List of Top ten Python extensions for Data Science & ML
top_ten_python_extensions = [
    {
        "Title" : "Python - By Microsoft",

        "Description" : "The official Python extension for VS Code, providing IntelliSense (code completion), linting, debugging, and support for Jupyter notebooks",

        "Key-Features" : ["Integrated Jupyter notebooks", "Debugging for Python scripts", "Support for virtual environments"],

        "Whey-Essential" : "A must-have for any Python developer, especially for data science workflows"
    },

    {
        "Title" : "Pylance",

        "Description" : "A fast, feature-rich language support extension for Python, powered by Pyright",

        "Key-Features" : ["Enhanced type-checking and IntelliSense", "Auto-imports and code navigation"],

        "Whey-Essential" : "Improves productivity by providing better code completion and error detection"
    },
    
    {
        "Title" : "Jupyter",

        "Description" : "Enables working with Jupyter notebooks directly in VS Code",

        "Key-Features" : ["Run and debug notebook cells", "Visualize dataframes and plots inline"],

        "Whey-Essential" : "Seamless integration with Jupyter notebooks, which are widely used in data science"
    },
    
    {
        "Title" : "Python Indent",

        "Description" : "Corrects and maintains proper indentation for Python code",

        "Key-Features" : ["Automatically adjusts indentation", "Helps maintain PEP 8 compliance"],

        "Whey-Essential" : "Ensures clean and readable code, which is critical for collaborative projects"
    },
    
    {
        "Title" : "Code Runner",

        "Description" : "Allows you to run code snippets or files for multiple languages, including Python",

        "Key-Features" : ["Quick execution of Python scripts", "Supports interactive input"],

        "Whey-Essential" : "Great for testing small snippets of code quickly"
    },
    
    {
        "Title" : "GitLens",

        "Description" : "Supercharges Git capabilities in VS Code",

        "Key-Features" : ["View code authorship and history", "Compare changes and blame annotations"],

        "Whey-Essential" : "Helps manage version control, which is crucial for collaborative data science projects"
    },
    
    {
        "Title" : "Rainbow CSV",

        "Description" : "Highlights CSV files in different colors for better readability",

        "Key-Features" : ["Color-coding for columns", "Query-like functionality for CSV files"],

        "Whey-Essential" : "Makes working with large datasets in CSV format much easier"
    },
    
    {
        "Title" : "Data Wrangler",

        "Description" : "A powerful extension for data manipulation and analysis",

        "Key-Features" : ["Built-in support for pandas and NumPy", "Visual tools for data cleaning"],

        "Whey-Essential" : "Streamlines data preprocessing tasks"
    },
    
    {
        "Title" : "Tabnine",

        "Description" : "An AI-powered code completion tool",

        "Key-Features" : ["Context-aware code suggestions", "Supports multiple languages, including Python"],

        "Whey-Essential" : "Speeds up coding by predicting what you're likely to type next"
    },
    
    {
        "Title" : "Markdown All in One",

        "Description" : "Enhances Markdown support in VS Code",

        "Key-Features" : ["Table of contents generation", "Keyboard shortcuts for Markdown formatting"],

        "Whey-Essential" : "Useful for documenting your data science projects and creating reports"
    },
    
    {
        "Title" : "Bonus Extensions",


        "Docker" : "For containerizing your ML models",

        "Remote-SSH" : "For working on remote servers",

        "Prettier" : "For formatting code automatically",

        "Live Share" : "For collaborative coding in real-time"
    },

]

# NOTE : These extensions will significantly enhance your productivity and streamline your data science and machine learning workflows in VS Code.

# %%
# Now we are trying to convert the above data into dataframe to store sequentially
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(top_ten_python_extensions)

# %%
df
# Out:
#                     Title                                        Description  \
# 0   Python - By Microsoft  The official Python extension for VS Code, pro...
# 1                 Pylance  A fast, feature-rich language support extensio...
# 2                 Jupyter  Enables working with Jupyter notebooks directl...
# 3           Python Indent  Corrects and maintains proper indentation for ...
# 4             Code Runner  Allows you to run code snippets or files for m...
# 5                 GitLens           Supercharges Git capabilities in VS Code
# 6             Rainbow CSV  Highlights CSV files in different colors for b...
# 7           Data Wrangler  A powerful extension for data manipulation and...
# 8                 Tabnine                 An AI-powered code completion tool
# 9     Markdown All in One               Enhances Markdown support in VS Code
# 10       Bonus Extensions                                                NaN
#
# ...
