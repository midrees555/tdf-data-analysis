# %% [markdown]
# # Python Ka Chilla - For TDF_Data_Analysis

# %% [markdown]
# --------------------
# --------------------

# %%
# importing important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_df = sns.load_dataset("titanic")
titanic_df.to_csv('./data/titanic.csv', index = False)

# %%
df = pd.read_csv('./data/titanic.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### *Some Random Activity*

# %%
iris_df = sns.load_dataset("iris")
iris_df.to_csv('./data/iris.csv', index=False)
print(iris_df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Create a bar plot of the average sepal length for each species
plt.figure(figsize=(10, 6))
sns.barplot(x='species', y='sepal_length', data=iris_df, ci=None)
plt.title('Average Sepal Length for Each Species')
plt.xlabel('Species')
plt.ylabel('Average Sepal Length')
plt.show()
# Out:
# C:\Users\MUHAMMAD\AppData\Local\Temp\ipykernel_15716\1048321845.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='species', y='sepal_length', data=iris_df, ci=None)

# %%
# Pairplot to visualize relationships between variables
sns.pairplot(iris_df, hue='species')
plt.show()

# %%
# Boxplot to visualize the distribution of each feature
plt.figure(figsize=(12, 8))
sns.boxplot(data=iris_df)
plt.title('Boxplot of Iris Dataset Features')
plt.show()

# %%
# Violin plot to visualize the distribution and density of each feature
plt.figure(figsize=(12, 8))
sns.violinplot(x='species', y='sepal_length', data=iris_df)
plt.title('Violin Plot of Sepal Length by Species')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='species', y='sepal_width', data=iris_df)
plt.title('Violin Plot of Sepal Width by Species')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='species', y='petal_length', data=iris_df)
plt.title('Violin Plot of Petal Length by Species')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='species', y='petal_width', data=iris_df)
plt.title('Violin Plot of Petal Width by Species')
plt.show()

# %%
# Heatmap to visualize the correlation between features
plt.figure(figsize=(10, 6))
sns.heatmap(iris_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Iris Dataset Features')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Heatmap to visualize the correlation between features
#       2 plt.figure(figsize=(10, 6))
# ----> 3 sns.heatmap(iris_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
#       4 plt.title('Correlation Heatmap of Iris Dataset Features')
#       5 plt.show()
#
# File c:\Users\MUHAMMAD\Anaconda3\envs\data-analysis\lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\MUHAMMAD\Anaconda3\envs\data-analysis\lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
# ...
